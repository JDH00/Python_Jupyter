# %% [markdown]
# # 딥러닝 기초 - 신경망 기초수학
# https://www.youtube.com/watch?v=RZB6fwX_ixY&t=1152s

# %% [markdown]
# # 신경망 기초 수학

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
plt.style.use(['seaborn-whitegrid']);

# %% [markdown]
# # 일차함수
# - $y=ax+b$
#     - $a$:기울기 $b$:$y$절편
# - 그래프 상에서 직선인 그래프(linear)

# %%
def linear_function(x):
    a=0.5
    b=2
    
    return a*x+b

# %%
print(linear_function(5))
# Out:
# 4.5

# %%
x = np.arange(-5,5,0.1)
y=linear_function(x)

plt.plot(x,y) #plt.plot(y)만 하면 x범위가 0부터 나옴
plt.xlabel('x')
plt.ylabel('y')
plt.title('Linear Function')
plt.show()

# %% [markdown]
# # 이차함수
# - $y=ax^2+bx+c$
# - 일반적으로 두 개의 실근을 가짐

# %%
def quadratic_function(x):
    a=1
    b=-1
    c=-2
    
    return a*x**2+b*x+c

# %%
print(quadratic_function(2))
# Out:
# 0

# %%
x = np.arange(-5,5,0.1)
y=quadratic_function(x)

plt.plot(x,y) #plt.plot(y)만 하면 x범위가 0부터 나옴
plt.xlabel('x')
plt.ylabel('y')
plt.title('Quadratic Function')
plt.show()

# %% [markdown]
# # 삼차함수
# - $y=ax^3+bx^2+cx+d$
# - 일반적으로 두 개의 실근을 가짐

# %%
def cubic_function(x):
    a=4
    b=0
    c=-1
    d=-8
    
    return a*x**3 + b*x**2 + c*x + d

# %%
print(cubic_function(3))
# Out:
# 97

# %%
x = np.arange(-5,5,0.1)
y=cubic_function(x)

plt.plot(x,y) #plt.plot(y)만 하면 x범위가 0부터 나옴
plt.xlabel('x')
plt.ylabel('y')
plt.title('Cubic Function')
plt.show()

# %% [markdown]
# # 함수의 최솟값/최댓값

# %%
def my_func(x):
    a=1
    b=-3
    c=10
    return a*x**2 + b*x + c

# %%
x=np.arange(-10,10,0.01)
y=my_func(x)

plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.scatter(1.5, my_func(1.5))
plt.text(1.5-1.5, my_func(1.5)+10, 'min value of f(x)\n({},{})'.format(1.5, my_func(1.5)),fontsize=10)
plt.title('my_func')
plt.show()

# %%
'''
#산점도 표시
#plt.scatter(x, y [,s=size_n, c=colors, marker='marker_string', alpha=alpha_f])
import matplotlib.pyplot as plt
plt.style.use(['seaborn-whitegrid'])

height = [165, 168, 166, 174, 167, 177, 183]
weight = [54, 65, 66, 71, 67, 77, 81]

size = 100*np.arange(1,8)
colors = ['r', 'g', 'b', 'c', 'm', 'k', 'k']

plt.scatter(height, weight, s=size, c=colors,  alpha=0.5)
plt.title('Height&Weight')
plt.grid()
plt.show()
''';

# %%
min_val=min(y)
print(min_val)
# Out:
# 7.75

# %% [markdown]
# # 특정 구간 내에서 최솟값 구하기

# %%
def get_minimum(x1,x2,f):
    x=np.arange(x1,x2,0.01)
    y=f(x)
    
    plt.plot(x,y)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Get Minimum')
    plt.show()
    
    return min(y)

# %%
print(get_minimum(1,4,my_func))
# Out:
# 7.75

# %% [markdown]
# # 지수함수/로그함수
# - 지수함수-로그함수는 역함수 관계($y=x$ 직선 대칭 단, 밑이 같을 때)
# - 파이썬으로 직접 구현 가능

# %% [markdown]
# # 지수함수
# - $y=a^x (a\neq0) (기본형)$
# - $y=e^x (e=2.71828...)$

# %%
def exponential_function(x):
    a=4
    return a**x

# %%
print(exponential_function(4))
print(exponential_function(0))
# Out:
# 256
# 1

# %%
x=np.arange(-3,2,0.1)
y=exponential_function(x)

plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.ylim(-1,15)
plt.xlim(-4,3)
plt.title('Exponential Function')
plt.show()

# %%
def exponential_function2(x):
    a=4
    return math.pow(a,x)

# %%
print(exponential_function2(4))
print(exponential_function2(0))
# Out:
# 256.0
# 1.0

# %% [markdown]
# # 밑이$e$인 지수함수

# %%
print(math.exp(4))
print(np.exp(4))
# Out:
# 54.598150033144236
# 54.598150033144236

# %% [markdown]
# # 로그함수
# - $y=log_{a}{(x)} (a\neq1)(기본형)$
# - $log_{10}{x}$ $(상용로그)$
# - $y=ln(x)$ $(밑이 e인 자연로그)$

# %%
print(math.log(2,3))#밑이3 진수가2
print(np.log2(4))#밑이2인 로그함수
print(np.log(4))#밑이e인 자연로그
# Out:
# 0.6309297535714574
# 2.0
# 1.3862943611198906

# %% [markdown]
# # 역함수 관계
# - $y=x$

# %%
x=np.arange(-1,5,0.01)
y1=np.exp(x)

x2=np.arange(0.00001,5,0.01)
y2=np.log(x2)

y3=x

plt.plot(x,y1,'r-', x2,y2,'b-', x,y3,'k--')

plt.ylim(-2,6)
plt.axvline(x=0, color='k')
plt.axhline(y=0, color='k')

plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# # 함수 조작
# - $y=-log{_a}{(x)}와 y=-log{_a}{(1-x)}$
#     - $x=0.5 대칭$
# - $Logistic Regression 을 위한 함수$

# %%
x=np.arange(-10,10,0.01)
y1=-np.log(x)
y2=-np.log(1-x)

plt.axvline(x=0, color='k')
plt.axhline(y=0, color='k')

plt.grid()
plt.plot(x,y1,'b-',x,y2,'r-')
plt.text(0.9, 2.0, 'y=-log(1-x)',fontsize=15)
plt.text(0.1, 3.0, 'y=-log(x)',fontsize=15)
plt.xlim(-0.3,1.4)
plt.ylim(-0.5,4)
plt.scatter(0.5, -np.log(0.5))
plt.show()
# Out:
# C:\Users\coding\AppData\Local\Temp\ipykernel_21472\1724920658.py:2: RuntimeWarning: invalid value encountered in log
#   y1=-np.log(x)
# C:\Users\coding\AppData\Local\Temp\ipykernel_21472\1724920658.py:3: RuntimeWarning: invalid value encountered in log
#   y2=-np.log(1-x)

# %% [markdown]
# # 극한
# - 극한에 대해서는 어떠한 식을 코드로 표현할 수 있다 정도로만 이해하며 참고
# - 극한에서 알아야 할 사실은 $x$가 어떤 값 $a$에 가까이 다가갈 때 a에 '한없이 가까이 간다'일 뿐, a에 도달하지는 않는다
# - 이를 표현할 때, 엡실론(epsilon)이라는 아주 작은 값(ex. 0.0001)등으로 표현

# %%
from sympy import *
init_printing()

x,y,z = symbols('x y z')
a,b,c,t = symbols('a b c t')

# %% [markdown]
# $lim_{x\to3}(\frac{x^3-1}{x-1})$

# %%
print('극한값:', limit((x**3-1) /(x-1),x,1 ))

plot( ((x**3-1)/(x-1)),xlim=(-5,5),ylim=(-1,10) );
# Out:
# 극한값: 3

# %% [markdown]
# $lim_{x\to\infty}(\frac{1+x}{x})$

# %%
print('극한값:', limit((1+x) /x,x,oo ))

plot((1+x)/x,xlim=(-10,10),ylim=(-5,5) );
# Out:
# 극한값: 1

# %% [markdown]
# $lim_{x\to\infty}(\frac{\sqrt{x+3}-2 }{x-1})=\frac{1}{4}$

# %%
print('극한값:', limit( (sqrt(x+3)-2) / (x-1), x ,1))

plot((sqrt(x+3)-2)/(x-1),xlim=(-5, 12), ylim=(-0.5,1));
# Out:
# 극한값: 1/4

# %% [markdown]
# # 삼각함수의 극한
# - $lim_{x\to(\frac{\pi}{2}+0)} tanx=-\infty$
# - $lim_{x\to(\frac{\pi}{2}-0)}tanx=\infty$

# %%
print('극한값: ', limit(tan(x),x, pi/2,'+' ))
print('극한값: ', limit(tan(x),x, pi/2,'-' ))

plot( tan(x), xlim=(-3.14,3.14),ylim=(-6,6));
# Out:
# 극한값:  -oo
# 극한값:  oo

# %% [markdown]
# - $lim_{x\to0}(\frac{sinx}{x})=1$

# %%
print('극한값: ', limit(sin(x)/x,x,0))

plot(sin(x)/x, ylim=(-2,2))
# Out:
# 극한값:  1

# %% [markdown]
# - $lim_{x\to0}xsin(\frac{1}{x})$

# %%
print('극한값:', limit(x*sin(1/x),x,0) )

plot(x*sin(1/x), xlim=(-2,2),ylim=(-1,1.5))
# Out:
# 극한값: 0

# %% [markdown]
# # 지수함수, 로그함수의 극한
# - $lim_{x\to\infty} \left(\frac{2^{x}+2^{-x}}{2^{x}-2^{-x}}\right)$

# %%
print('극한값: ', limit(( 2**x - 2**(-x) ) / ( 2**x + 2**(-x) ),x,oo))
      
plot( ( 2**x - 2**(-x) ) / ( 2**x + 2**(-x) ),xlim=(-10,10), ylim=(-3,3) );
# Out:
# 극한값:  1

# %% [markdown]
# - $lim_{x\to\infty}(log_{2}(x+1)-log_{2}(x))=0$

# %%
print('극한값: ',limit( (log(x+1, 2) - log(x,2)),x,oo))

plot( log(x+1,2)-log(x,2), xlim=(-4,6), ylim=(-4,4) )
# Out:
# 극한값:  0

# %% [markdown]
# # 자연로그($e$)의 밑
# - $lim_{x\to\infty}(1+\frac{1}{x})^x=e$
# - $lim_{x\to\infty}(1+\frac{2}{x})^x=e^2$
# - $lim_{x\to0}\frac{(e^x-1)}{x}=1$
# - $lim_{x\to0}\frac{ln(1+x)}{x}=1$

# %%
print("(1):", limit( (1+1/x)**x, x, oo ))
print("(2):", limit( (1+2/x)**x, x, oo ))
print("(3):", limit( (exp(x)-1)/x, x, 0))
print("(4):", limit( ln(1+x) / x, x, 0 ))

plot( ln(1+x) / x, xlim=(-4,6), ylim=(-2,8) )
# Out:
# (1): E
# (2): exp(2)
# (3): 1
# (4): 1

# %% [markdown]
# # 미분
# - 어떤 한 순간의 변화량을 표시한 것

# %% [markdown]
# # 미분과 기울기
# - 어떤 함수를 나타내는 그래프에서 한 범의 미분값(미분계수)를 구하는 것은 해당 점에서의 접선을 의미
# - 기울기는 방향성을 가짐
#     - 이용할 미분 식(수치 미분)
#     - $\frac{df(x)}{dx} = lim_{x\to\infty}( \frac{f(x+h)-f(x-h)}{2h} )  $
# - [주의] $h$는 아주 작은 수를 뜻하는데, 예를들어 $10e-50$ 정도의 수를 하면 파이썬은 이를 0.0으로 인식
# - 따라서, 딥러닝에서 아주 작은 수를 정할때 $1e-4$ 정도로 설정해도 무방

# %%
def numerical_differential(f,x):
    h=1e-4
    return (f(x+h)-f(x-h) / (2*h) )

# %% [markdown]
# # 함수 위의 점 $(a,b)$에서의 접선의 방정식
# - 예제: 점 (1,7)에서의 기울기

# %%
def my_func(x):
    return 2*x**2 + 3*x +2

# %%
def linear_func(a,b,c,x):
    return c*(x-a)+b

# %%
c= numerical_differential(my_func, 1)

x=np.arange(-5,5, 0.01)
y=linear_func(1,my_func(1), c, x)

plt.xlabel('x')
plt.ylabel('y')
plt.scatter(1,my_func(1))
plt.plot(x,my_func(x),x,y,'r-')
ylim=(-40,40)
plt.title('f(x) & linear function')
plt.show()
